# %%
import torch

# Load the YOLOv5 model and initiate training
if __name__ == "__main__":
    model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5s.pt')  # Load pre-trained weights

    # Train the model on your dataset
    model.train(data='D:\Eco-Watch\waste in water.v1i.yolov8\data.yaml', epochs=100, batch_size=16, imgsz=640)
